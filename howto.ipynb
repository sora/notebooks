# %% [markdown]
# ## Jupyterの使い方

# %% [markdown]
# 基本コマンドリファレンス
# * h: help
# * Alt-Enter: 実行
# * Esc: コマンドモードに移行
# * dd: ラインを削除
# * j, k: ラインの上下

# %% [markdown]
# ## グラフの書き方

# %% [markdown]
# 行はじめに
# ```
# %matplotlib inline
# ```
# を実行する

# %%
# 例
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-3, 3, 0.2)
y = np.sin(x)
plt.plot(x, y)
